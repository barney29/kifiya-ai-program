# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('../src/')
from dataframewrapper import DataFrameWrapper
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
togo_df = pd.read_csv("../data/togo-dapaong_qc.csv")
togo_df
# Out:
#                Timestamp  GHI  DNI  DHI  ModA  ModB  Tamb     RH   WS  WSgust  \
# 0       2021-10-30 00:01 -0.7 -0.1 -0.8   0.0   0.0  21.9   99.1  0.0     0.0
# 1       2021-10-30 00:02 -0.7 -0.1 -0.8   0.0   0.0  21.9   99.2  0.0     0.0
# 2       2021-10-30 00:03 -0.7 -0.1 -0.8   0.0   0.0  21.9   99.2  0.0     0.0
# 3       2021-10-30 00:04 -0.7  0.0 -0.8   0.0   0.0  21.9   99.3  0.0     0.0
# 4       2021-10-30 00:05 -0.7 -0.1 -0.8   0.0   0.0  21.9   99.3  0.0     0.0
# ...                  ...  ...  ...  ...   ...   ...   ...    ...  ...     ...
# 525595  2022-10-29 23:56 -1.6 -0.1 -2.9   0.0   0.0  24.0  100.0  0.0     0.0
# 525596  2022-10-29 23:57 -1.7 -0.1 -3.0   0.0   0.0  24.0  100.0  0.0     0.0
# 525597  2022-10-29 23:58 -1.7 -0.1 -3.1   0.0   0.0  24.0  100.0  0.0     0.0
# 525598  2022-10-29 23:59 -1.7 -0.2 -3.3   0.0   0.0  23.9  100.0  0.0     0.0
# 525599  2022-10-30 00:00 -1.7 -0.1 -3.4   0.0   0.0  23.9  100.0  0.0     0.0
#
# ...

# %%
#renaming important columns to avoid confusion 
rename_col = {'GHI': 'global_horizontal_irradiance', 'DNI': 'direct_normal_irradiance', 'DHI': 'diffuse_horizontal_irradiance', 'Tamb': 'ambient_temperature','RH': 'relative_humidity', 'WS': 'wind_speed', 'WD': 'wind_direction', 'TModA':'temp_module_A', 'TModB': 'temp_module_B'}

# %%
sier_df = sier_df.rename(columns = rename_col)
#inspecting result
sier_df.head()
# Out:
#           Timestamp  global_horizontal_irradiance  direct_normal_irradiance  \
# 0  2021-10-30 00:01                          -0.7                      -0.1
# 1  2021-10-30 00:02                          -0.7                      -0.1
# 2  2021-10-30 00:03                          -0.7                      -0.1
# 3  2021-10-30 00:04                          -0.7                       0.0
# 4  2021-10-30 00:05                          -0.7                      -0.1
#
#    diffuse_horizontal_irradiance  ModA  ModB  ambient_temperature  \
# 0                           -0.8   0.0   0.0                 21.9
# 1                           -0.8   0.0   0.0                 21.9
# 2                           -0.8   0.0   0.0                 21.9
# 3                           -0.8   0.0   0.0                 21.9
# 4                           -0.8   0.0   0.0                 21.9
#
#    relative_humidity  wind_speed  WSgust  WSstdev  wind_direction  WDstdev  \
# ...

# %%
sier_df.shape
# Out:
# (525600, 19)

# %%
sier_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525600 entries, 0 to 525599
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Timestamp                      525600 non-null  object
#  1   global_horizontal_irradiance   525600 non-null  float64
#  2   direct_normal_irradiance       525600 non-null  float64
#  3   diffuse_horizontal_irradiance  525600 non-null  float64
#  4   ModA                           525600 non-null  float64
#  5   ModB                           525600 non-null  float64
#  6   ambient_temperature            525600 non-null  float64
#  7   relative_humidity              525600 non-null  float64
#  8   wind_speed                     525600 non-null  float64
#  9   WSgust                         525600 non-null  float64
#  10  WSstdev                        525600 non-null  float64
#  11  wind_direction                 525600 non-null  float64
# ...

# %%
sier_df = sier_df.drop_duplicates()
sier_df.count()
# Out:
# Timestamp                        525600
# global_horizontal_irradiance     525600
# direct_normal_irradiance         525600
# diffuse_horizontal_irradiance    525600
# ModA                             525600
# ModB                             525600
# ambient_temperature              525600
# relative_humidity                525600
# wind_speed                       525600
# WSgust                           525600
# WSstdev                          525600
# wind_direction                   525600
# WDstdev                          525600
# BP                               525600
# Cleaning                         525600
# Precipitation                    525600
# temp_module_A                    525600
# temp_module_B                    525600
# Comments                              0
# dtype: int64

# %%
#droping column Comments 
sier_df = sier_df.drop(['Comments'], axis=1)

# %%
#cleaning negative values I have used 0 to replace the value
sier_df['global_horizontal_irradiance'] = sier_df['global_horizontal_irradiance'].apply(lambda ghi: 0 if ghi < 0 else ghi)
sier_df['diffuse_horizontal_irradiance'] = sier_df['diffuse_horizontal_irradiance'].apply(lambda dhi: 0 if dhi < 0 else dhi)
sier_df['direct_normal_irradiance'] = sier_df['direct_normal_irradiance'].apply(lambda dni: 0 if dni < 0 else dni)

# %%
#checking the cleand data
togo_df.sample(10)
# Out:
#                Timestamp  global_horizontal_irradiance  \
# 464458  2022-09-17 12:59                         236.5
# 358596  2022-07-06 00:37                           0.0
# 219828  2022-03-31 15:49                         610.7
# 346952  2022-06-27 22:33                           0.0
# 146731  2022-02-08 21:32                           0.0
# 328178  2022-06-14 21:39                           0.0
# 496065  2022-10-09 11:46                         291.5
# 220011  2022-03-31 18:52                           0.5
# 346861  2022-06-27 21:02                           0.0
# 154171  2022-02-14 01:32                           0.0
#
#         direct_normal_irradiance  diffuse_horizontal_irradiance   ModA   ModB  \
# 464458                       0.5                          235.3  241.0  233.5
# 358596                       0.0                            0.0    0.0    0.0
# 219828                     452.8                          285.7  579.8  560.7
# ...

# %% [markdown]
# # Statistical Analysis

# %%
sier_df.describe()
# Out:
#        global_horizontal_irradiance  direct_normal_irradiance  \
# count                 525600.000000             525600.000000
# mean                     204.406778                116.523731
# std                      296.787520                218.573992
# min                        0.000000                  0.000000
# 25%                        0.000000                  0.000000
# 50%                        0.300000                  0.000000
# 75%                      362.400000                107.000000
# max                     1499.000000                946.000000
#
#        diffuse_horizontal_irradiance           ModA           ModB  \
# count                  525600.000000  525600.000000  525600.000000
# mean                      116.273677     206.643095     198.114691
# std                       157.020868     300.896893     288.889073
# min                         0.000000       0.000000       0.000000
# 25%                         0.000000       0.000000       0.000000
# ...

# %%
# sier_df['Timestamp'] = pd.to_datetime(sier_df['Timestamp']) # changing to dattime format
# daily_mean = sier_df.resample('D', on='Timestamp').mean()
# daily_mean.reset_index(inplace=True)
# daily_mean

# %% [markdown]
# # Wrapping the dataframe with the custome class

# %%
sier_Df = DataFrameWrapper(sier_df)

# %% [markdown]
#    ## Weekly Data Solar Radiation GHI, DNI and DHI

# %%
#Global Horizontal Irradiance
sier_Df.plot_weekly_time_series('global_horizontal_irradiance', 'Global Horizontal Irradiance')

# %%
sier_Df.plot_weekly_time_series('direct_normal_irradiance', 'Direct Normal Irradiance')

# %%
sier_Df.plot_weekly_time_series('diffuse_horizontal_irradiance','Diffuse Horizontal Irradiance')

# %% [markdown]
# ## Time Series Analysis

# %% [markdown]
# ## Weekly and Monthly analysis

# %%
sier_Df.main_time_seris_analysis()

# %%
#weekly analsis of main variables
sier_Df.weekly_analysis_of_main_vairables()

# %% [markdown]
# ## Correlation

# %%
sier_Df.corr_solarRad_temp()

# %%
sier_Df.corr_ws_wd()

# %%
sier_Df.corr_tamb_tmoa_tmob_by_condition()
# Out:
# Correlation matrix for wind speed 0.0
#                      temp_module_A  temp_module_B  ambient_temperature
# temp_module_A             1.000000       0.996520             0.766172
# temp_module_B             0.996520       1.000000             0.782783
# ambient_temperature       0.766172       0.782783             1.000000
#
# Correlation matrix for wind speed 0.1
#                      temp_module_A  temp_module_B  ambient_temperature
# temp_module_A             1.000000       0.995482             0.788046
# temp_module_B             0.995482       1.000000             0.806220
# ambient_temperature       0.788046       0.806220             1.000000
#
# Correlation matrix for wind speed 0.2
#                      temp_module_A  temp_module_B  ambient_temperature
# temp_module_A             1.000000       0.995211             0.799729
# temp_module_B             0.995211       1.000000             0.818033
# ambient_temperature       0.799729       0.818033             1.000000
# ...

# %%
sier_Df.wind_analysis()

# %%
sier_Df.histogram_main_variable()
